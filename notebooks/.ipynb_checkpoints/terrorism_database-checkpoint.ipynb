# %% [raw]
# ------------ POUR IMPORTER UNE LIBRAIRIE -------------------
# import sys
# !{sys.executable} -m pip install

# %%
# %matplotlib inline
from sklearn import datasets
import matplotlib.pyplot as plt
import matplotlib as mpl
import pylab
import seaborn as sns
import pandas as pd
import numpy as np
import tensorflow as tf
import re

# %%
df = pd.read_csv('../datasets/gtb.csv', encoding='ISO-8859-1')
# Out:
# c:\program files\python36\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (4,31,33,61,62,76,79,90,92,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', df.shape[1]):
    print(df.head(5))
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164            1         0      NaN
# 1    Mexico city  19.371887  -99.086624            1         0      NaN
# 2        Unknown  15.478598  120.599741            4         0      NaN
# 3         Athens  37.997490   23.762728            1         0      NaN
# 4        Fukouka  33.580412  130.396361            1         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1          0          NaN             NaN
# 1     NaN      1      1      1          0          NaN             NaN
# 2     NaN      1      1      1          0          NaN             NaN
# 3     NaN      1      1      1          0          NaN             NaN
# 4     NaN      1      1      1         -9          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0         0        1        0            1                   Assassination
# 1         0        1        0            6     Hostage Taking (Kidnapping)
# 2         0        1        0            1                   Assassination
# 3         0        1        0            3               Bombing/Explosion
# 4         0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#    gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  \
# 0        NaN    NaN            0          NaN          NaN           0
# 1        NaN    NaN            0          NaN          NaN           0
# 2        NaN    NaN            0          NaN          NaN           0
# 3        NaN    NaN            0          NaN          NaN           0
# 4        NaN    NaN            0          NaN          NaN           0
#
#    nperps  nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 1     7.0       NaN      NaN        NaN           NaN     NaN         NaN
# 2     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 3     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 4     NaN       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN            NaN        NaN         13
# 1            NaN     NaN         NaN            NaN        NaN         13
# 2            NaN     NaN         NaN            NaN        NaN         13
# 3            NaN     NaN         NaN            NaN        NaN          6
# 4            NaN     NaN         NaN            NaN        NaN          8
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN       0.0         NaN            NaN        NaN         NaN
# 1       NaN       0.0         NaN            NaN        NaN         NaN
# 2       NaN       0.0         NaN            NaN        NaN         NaN
# 3       NaN       1.0         NaN            NaN        NaN         NaN
# 4       NaN       1.0         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS      0.0       0.0       0.0      0.0     NaN
# 1     PGIS      0.0       1.0       1.0      1.0     NaN
# 2     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 3     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 4     PGIS     -9.0      -9.0       1.0      1.0     NaN

# %%
df.drop(columns=['eventid','iday','imonth', 'approxdate', 'extended', 'resolution', 'provstate', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'natlty2', 'natlty2_txt', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperpcap', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim'], inplace=True)

# %%
# 'weaptype2_txt', 'weaptype2', 'weapsubtype2', 'weapsubtype2_txt'  #si je veux enlever les secondes armes
df.drop(columns=['weaptype3_txt', 'weaptype3', 'weapsubtype3', 'weapsubtype3_txt', 'weaptype4_txt', 'weaptype4', 'weapsubtype4', 'weapsubtype4_txt', 'weapdetail', 'nkillus', 'nwoundus', 'property', 'propextent', 'propextent_txt', 'propvalue', 'propcomment', 'ishostkid', 'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry', 'ransompaidus', 'ransomnote', 'hostkidoutcome', 'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'], inplace=True)

# %%
df.drop(columns=['ransompaid', 'ransomamtus'], inplace=True)
df.drop(columns=['nwoundte', 'nperps', 'claimed'], inplace=True)
with pd.option_context('display.max_rows', None, 'display.max_columns', df.shape[1]):
    print(df.head(10))
# Out:
#    iyear  country         country_txt  region                   region_txt  \
# 0   1970       58  Dominican Republic       2  Central America & Caribbean
# 1   1970      130              Mexico       1                North America
# 2   1970      160         Philippines       5               Southeast Asia
# 3   1970       78              Greece       8               Western Europe
# 4   1970      101               Japan       4                    East Asia
# 5   1970      217       United States       1                North America
# 6   1970      218             Uruguay       3                South America
# 7   1970      217       United States       1                North America
# 8   1970      217       United States       1                North America
# 9   1970      217       United States       1                North America
#
#             city  success  suicide  attacktype1  \
# 0  Santo Domingo        1        0            1
# 1    Mexico city        1        0            6
# 2        Unknown        1        0            1
# 3         Athens        1        0            3
# 4        Fukouka        1        0            7
# 5          Cairo        1        0            2
# 6     Montevideo        0        0            1
# 7        Oakland        1        0            3
# 8        Madison        1        0            7
# 9        Madison        1        0            7
#
#                   attacktype1_txt  attacktype2 attacktype2_txt  attacktype3  \
# 0                   Assassination          NaN             NaN          NaN
# 1     Hostage Taking (Kidnapping)          NaN             NaN          NaN
# 2                   Assassination          NaN             NaN          NaN
# 3               Bombing/Explosion          NaN             NaN          NaN
# 4  Facility/Infrastructure Attack          NaN             NaN          NaN
# 5                   Armed Assault          NaN             NaN          NaN
# 6                   Assassination          NaN             NaN          NaN
# 7               Bombing/Explosion          NaN             NaN          NaN
# 8  Facility/Infrastructure Attack          NaN             NaN          NaN
# 9  Facility/Infrastructure Attack          NaN             NaN          NaN
#
#   attacktype3_txt  targtype1                targtype1_txt  targsubtype1  \
# 0             NaN         14  Private Citizens & Property          68.0
# 1             NaN          7      Government (Diplomatic)          45.0
# 2             NaN         10          Journalists & Media          54.0
# 3             NaN          7      Government (Diplomatic)          46.0
# 4             NaN          7      Government (Diplomatic)          46.0
# 5             NaN          3                       Police          22.0
# 6             NaN          3                       Police          25.0
# 7             NaN         21                    Utilities         107.0
# 8             NaN          4                     Military          28.0
# 9             NaN          2         Government (General)          21.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
# 5    Police Building (headquarters, station, school)
# 6                    Police Security Forces/Officers
# 7                                        Electricity
# 8                Military Recruiting Station/Academy
# 9                Government Building/Facility/Office
#
#                             corp1  \
# 0                             NaN
# 1     Belgian Ambassador Daughter
# 2                Voice of America
# 3                             NaN
# 4                             NaN
# 5         Cairo Police Department
# 6                Uruguayan Police
# 7  Pacific Gas & Electric Company
# 8                        R.O.T.C.
# 9               Selective Service
#
#                                              target1  natlty1  \
# 0                                       Julio Guzman     58.0
# 1                            Nadine Chaval, daughter     21.0
# 2                                           Employee    217.0
# 3                                       U.S. Embassy    217.0
# 4                                     U.S. Consulate    217.0
# 5                          Cairo Police Headquarters    217.0
# 6  Juan Maria de Lucah/Chief of Directorate of in...    218.0
# 7                                    Edes Substation    217.0
# 8  R.O.T.C. offices at University of Wisconsin, M...    217.0
# 9  Selective Service Headquarters in Madison Wisc...    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
# 5       United States        NaN           NaN           NaN              NaN
# 6             Uruguay        NaN           NaN           NaN              NaN
# 7       United States        NaN           NaN           NaN              NaN
# 8       United States        NaN           NaN           NaN              NaN
# 9       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  targtype3 targtype3_txt  targsubtype3 targsubtype3_txt corp3  \
# 0   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 1   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 2   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 3   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 4   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 5   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 6   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 7   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 8   NaN     NaN        NaN           NaN           NaN              NaN   NaN
# 9   NaN     NaN        NaN           NaN           NaN              NaN   NaN
#
#   target3                                          motive  weaptype1  \
# 0     NaN                                             NaN         13
# 1     NaN                                             NaN         13
# 2     NaN                                             NaN         13
# 3     NaN                                             NaN          6
# 4     NaN                                             NaN          8
# 5     NaN  To protest the Cairo Illinois Police Deparment          5
# 6     NaN                                             NaN          5
# 7     NaN                                             NaN          6
# 8     NaN     To protest the War in Vietnam and the draft          8
# 9     NaN     To protest the War in Vietnam and the draft          8
#
#   weaptype1_txt  weapsubtype1                   weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                                NaN        NaN
# 1       Unknown           NaN                                NaN        NaN
# 2       Unknown           NaN                                NaN        NaN
# 3    Explosives          16.0             Unknown Explosive Type        NaN
# 4    Incendiary           NaN                                NaN        NaN
# 5      Firearms           5.0                   Unknown Gun Type        NaN
# 6      Firearms           2.0  Automatic or Semi-Automatic Rifle        NaN
# 7    Explosives          16.0             Unknown Explosive Type        NaN
# 8    Incendiary          19.0       Molotov Cocktail/Petrol Bomb        NaN
# 9    Incendiary          20.0                Gasoline or Alcohol        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  nkill  nkillter  nwound  \
# 0           NaN           NaN              NaN    1.0       NaN     0.0
# 1           NaN           NaN              NaN    0.0       NaN     0.0
# 2           NaN           NaN              NaN    1.0       NaN     0.0
# 3           NaN           NaN              NaN    NaN       NaN     NaN
# 4           NaN           NaN              NaN    NaN       NaN     NaN
# 5           NaN           NaN              NaN    0.0       0.0     0.0
# 6           NaN           NaN              NaN    0.0       NaN     0.0
# 7           NaN           NaN              NaN    0.0       0.0     0.0
# 8           NaN           NaN              NaN    0.0       0.0     0.0
# 9           NaN           NaN              NaN    0.0       0.0     0.0
#
#    ransom  ransomamt
# 0     0.0        NaN
# 1     1.0   800000.0
# 2     0.0        NaN
# 3     0.0        NaN
# 4     0.0        NaN
# 5     0.0        NaN
# 6     0.0        NaN
# 7     0.0        NaN
# 8     0.0        NaN
# 9     0.0        NaN

# %%
print('Nombre de lignes : ' + str(df.shape[0]) + '\nPourcentage de vide : \n' + str((df.isna().sum()*100)/df.shape[0]))
# Out:
# Nombre de lignes : 50609
# Pourcentage de vide :
# iyear                0.000000
# country              0.000000
# country_txt          0.000000
# region               0.000000
# region_txt           0.000000
# city                 0.000000
# success              0.000000
# suicide              0.000000
# attacktype1          0.000000
# attacktype1_txt      0.000000
# attacktype2         99.918987
# attacktype2_txt     99.918987
# attacktype3         99.996048
# attacktype3_txt     99.996048
# targtype1            0.000000
# targtype1_txt        0.000000
# targsubtype1         4.345077
# targsubtype1_txt     4.345077
# corp1               52.374084
# target1              0.758758
# natlty1              0.434705
# natlty1_txt          0.434705
# targtype2           98.903357
# targtype2_txt       98.903357
# targsubtype2        99.179988
# targsubtype2_txt    99.179988
# corp2               99.300520
# target2             99.037721
# targtype3           99.830070
# targtype3_txt       99.830070
# targsubtype3        99.873540
# targsubtype3_txt    99.873540
# corp3               99.907131
# target3             99.832046
# motive              98.097176
# weaptype1            0.000000
# weaptype1_txt        0.000000
# weapsubtype1        15.005236
# weapsubtype1_txt    15.005236
# weaptype2           94.295481
# weaptype2_txt       94.295481
# weapsubtype2        95.249857
# weapsubtype2_txt    95.249857
# nkill               11.456460
# nkillter            94.358711
# nwound              15.054635
# ransom               0.709360
# ransomamt           98.927068
# dtype: float64

# %%
df_forcorr = df.filter(items=['iyear', 'country', 'region', 'success', 'suicide', 'attacktype1', 'targtype1', 'natlty1', 'weaptype1', 'nkill', 'nkillter', 'nwound','ransomamt'])
sns.heatmap(df_forcorr.corr(), annot=False)

# %%
plot = sns.countplot(df['attacktype1_txt'], hue=df['success'])
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Assassination'),
#  Text(0, 0, 'Hostage Taking (Kidnapping)'),
#  Text(0, 0, 'Bombing/Explosion'),
#  Text(0, 0, 'Facility/Infrastructure Attack'),
#  Text(0, 0, 'Armed Assault'),
#  Text(0, 0, 'Hijacking'),
#  Text(0, 0, 'Unknown'),
#  Text(0, 0, 'Unarmed Assault'),
#  Text(0, 0, 'Hostage Taking (Barricade Incident)')]

# %%
freq_success = 1-((df['attacktype1_txt'][df['success'] == 0].value_counts())/(df['attacktype1_txt'][df['success'] == 1].value_counts()))
plot = sns.barplot(x=freq_success.index, y=freq_success.values)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Armed Assault'),
#  Text(0, 0, 'Assassination'),
#  Text(0, 0, 'Bombing/Explosion'),
#  Text(0, 0, 'Facility/Infrastructure Attack'),
#  Text(0, 0, 'Hijacking'),
#  Text(0, 0, 'Hostage Taking (Barricade Incident)'),
#  Text(0, 0, 'Hostage Taking (Kidnapping)'),
#  Text(0, 0, 'Unarmed Assault'),
#  Text(0, 0, 'Unknown')]

# %%
plot = sns.barplot(x=df['country_txt'].value_counts()[1:20,].index, y=df['country_txt'].value_counts()[1:20,]) #sélection des 20 premiers pays à être touchés
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'El Salvador'),
#  Text(0, 0, 'Colombia'),
#  Text(0, 0, 'United Kingdom'),
#  Text(0, 0, 'Spain'),
#  Text(0, 0, 'Chile'),
#  Text(0, 0, 'United States'),
#  Text(0, 0, 'India'),
#  Text(0, 0, 'Nicaragua'),
#  Text(0, 0, 'Guatemala'),
#  Text(0, 0, 'Sri Lanka'),
#  Text(0, 0, 'Philippines'),
#  Text(0, 0, 'Lebanon'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'South Africa'),
#  Text(0, 0, 'Turkey'),
#  Text(0, 0, 'Italy'),
#  Text(0, 0, 'Israel'),
#  Text(0, 0, 'Argentina'),
#  Text(0, 0, 'Greece')]

# %%
grouped_year = df.groupby('iyear')
def get_params():
    params = {'legend.fontsize' : 'Large',
              'figure.figsize'  : figsize,
              'axes.labelsize'  : 'x-large',
              'axes.titlesize'  : 'xx-large',
              'xtick.labelsize' : 'Large',
              'ytick.labelsize' : 'Large'}
    return params

figsize=(18, 18)
params = get_params()

plt.rcParams.update(params)
plt.tick_params(labelsize=12)
sns.lineplot(x=df['iyear'].unique(), y=df['iyear'])
plt.title('Distribution des attentats par année')
plt.xticks(rotation=90)
# plt.yticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-1ed440230132> in <module>
#      14 plt.rcParams.update(params)
#      15 plt.tick_params(labelsize=12)
# ---> 16 sns.lineplot(x=df['iyear'].unique(), y=df['iyear'])
#      17 plt.title('Distribution des attentats par année')
#      18 plt.xticks(rotation=90)
#
# c:\program files\python36\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# c:\program files\python36\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# c:\program files\python36\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     155                 units=units
#     156             )
# --> 157             plot_data = pd.DataFrame(plot_data)
#     158
#     159         # Option 3:
#
# c:\program files\python36\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# c:\program files\python36\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# c:\program files\python36\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# c:\program files\python36\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     326                            'length {idx_len}'
#     327                            .format(length=lengths[0], idx_len=len(index)))
# --> 328                     raise ValueError(msg)
#     329             else:
#     330                 index = ibase.default_index(lengths[0])
#
# ValueError: array length 23 does not match index length 50609

# %%
# sns.set(style="ticks")
sns.set(style="whitegrid")

figsize=(18, 30)
xcol = "iyear"

params = get_params()

plt.rcParams.update(params)
plt.tick_params(labelsize=12)
sns.barplot(y=grouped_year['nkill'].sum(), x=grouped_year['nkill'].sum().keys())
plt.title('Nb kills per year')
plt.xticks(rotation=90)
# plt.yticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# sns.set(style="ticks")
sns.set(style="whitegrid")

figsize=(20, 8)
xcol = "Origin/Ethnicity"
params = get_params()
plt.rcParams.update(params)
org = df[xcol].unique()
l = len(df[xcol])
con = []
for country in df[xcol].unique():
    c = df[df[xcol]==country]
    if len(c)>l*0.03:
        x = df[df[xcol]==country]["Release Year"].value_counts()
        sns.lineplot(x.index, x.values)
        con.append(country)
plt.legend(con)
plt.title("Movie Count Per "+ xcol)
# plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origin/Ethnicity'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-0fa877f770f7> in <module>
#       6 params = get_params()
#       7 plt.rcParams.update(params)
# ----> 8 org = df[xcol].unique()
#       9 l = len(df[xcol])
#      10 con = []
#
# c:\program files\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# c:\program files\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origin/Ethnicity'

# %%
from scipy.stats.stats import pearsonr

# %%
print('Corrélation entre nombre de morts par an et nombre d\'attentats par an : ' + str(pearsonr(grouped_year['nkill'].sum().values,grouped_year['iyear'].value_counts().values)[0]))
# Out:
# Corrélation entre nombre de morts par an et nombre d'attentats par an : 0.9063453945619605
